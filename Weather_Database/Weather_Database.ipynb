# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.

# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import time

# Import api keys, city py module and requests library
from config import weather_api_key
import requests
from citipy import citipy

# Get url for open weather maps API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations of size 2000.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | richards bay
# Processing Record 3 of Set 1 | flinders
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | necochea
# Processing Record 12 of Set 1 | port hedland
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | kuchurhan
# Processing Record 15 of Set 1 | saint-pierre
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | tocopilla
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | tulnici
# Processing Record 20 of Set 1 | mashhad
# Processing Record 21 of Set 1 | hobyo
# Processing Record 22 of Set 1 | vardo
# Processing Record 23 of Set 1 | harwich
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | bandarbeyla
# Processing Record 28 of Set 1 | vanavara
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | eureka
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | tornio
# Processing Record 34 of Set 1 | la ronge
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | acapulco
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 38 of Set 1 | luena
# Processing Record 39 of Set 1 | gejiu
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | vao
# Processing Record 43 of Set 1 | karratha
# Processing Record 44 of Set 1 | broome
# Processing Record 45 of Set 1 | saint-joseph
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | los llanos de aridane
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | longonjo
# Processing Record 50 of Set 1 | trairi
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | micheweni
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 2 | tambura
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | sur
# Processing Record 13 of Set 2 | nioro
# Processing Record 14 of Set 2 | manggar
# Processing Record 15 of Set 2 | weligama
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | ha noi
# Processing Record 19 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 2 | ocampo
# Processing Record 21 of Set 2 | soe
# Processing Record 22 of Set 2 | norman wells
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | vestmannaeyjar
# Processing Record 25 of Set 2 | kushmurun
# Processing Record 26 of Set 2 | sirjan
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 2 | havelock
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 2 | puerto quijarro
# Processing Record 34 of Set 2 | mailsi
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | gat
# Processing Record 37 of Set 2 | alekseyevsk
# Processing Record 38 of Set 2 | takhtamygda
# Processing Record 39 of Set 2 | starobaltachevo
# Processing Record 40 of Set 2 | port hardy
# Processing Record 41 of Set 2 | southbridge
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | durban
# Processing Record 45 of Set 2 | coquimbo
# Processing Record 46 of Set 2 | kimbe
# Processing Record 47 of Set 2 | namatanai
# Processing Record 48 of Set 2 | cairns
# Processing Record 49 of Set 2 | sao gabriel da cachoeira
# Processing Record 50 of Set 2 | the valley
# Processing Record 1 of Set 3 | quetigny
# Processing Record 2 of Set 3 | sorong
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | chernyshevskiy
# Processing Record 5 of Set 3 | ormond beach
# Processing Record 6 of Set 3 | mandalgovi
# Processing Record 7 of Set 3 | guerrero negro
# Processing Record 8 of Set 3 | andenes
# Processing Record 9 of Set 3 | opobo
# City not found. Skipping...
# Processing Record 10 of Set 3 | nakusp
# Processing Record 11 of Set 3 | khomeynishahr
# City not found. Skipping...
# Processing Record 12 of Set 3 | acajutla
# Processing Record 13 of Set 3 | aswan
# Processing Record 14 of Set 3 | salalah
# Processing Record 15 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | rawson
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | sahuaripa
# Processing Record 20 of Set 3 | coruripe
# Processing Record 21 of Set 3 | usogorsk
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | palimbang
# Processing Record 25 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 26 of Set 3 | clyde river
# Processing Record 27 of Set 3 | kurilsk
# Processing Record 28 of Set 3 | waverly
# Processing Record 29 of Set 3 | schweinfurt
# Processing Record 30 of Set 3 | laguna
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | potam
# Processing Record 34 of Set 3 | assiniboia
# Processing Record 35 of Set 3 | bairiki
# Processing Record 36 of Set 3 | qianguo
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | nemuro
# Processing Record 39 of Set 3 | faya
# Processing Record 40 of Set 3 | ancud
# Processing Record 41 of Set 3 | bataipora
# Processing Record 42 of Set 3 | lerwick
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | galich
# Processing Record 45 of Set 3 | challans
# Processing Record 46 of Set 3 | harbour breton
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | paita
# Processing Record 50 of Set 3 | portland
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | ponta do sol
# Processing Record 3 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 4 of Set 4 | waiouru
# Processing Record 5 of Set 4 | pangai
# Processing Record 6 of Set 4 | egvekinot
# Processing Record 7 of Set 4 | smithers
# Processing Record 8 of Set 4 | okhotsk
# Processing Record 9 of Set 4 | srednekolymsk
# Processing Record 10 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 4 | jacmel
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | bida
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | tahoua
# Processing Record 16 of Set 4 | lasa
# Processing Record 17 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 4 | vila franca do campo
# Processing Record 19 of Set 4 | bulungu
# Processing Record 20 of Set 4 | cartagena
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | qiongshan
# Processing Record 23 of Set 4 | port lincoln
# Processing Record 24 of Set 4 | mehamn
# Processing Record 25 of Set 4 | miranorte
# City not found. Skipping...
# Processing Record 26 of Set 4 | gwadar
# Processing Record 27 of Set 4 | leerdam
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | ugoofaaru
# Processing Record 31 of Set 4 | san cristobal
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | qasigiannguit
# Processing Record 34 of Set 4 | ribeira grande
# Processing Record 35 of Set 4 | takab
# Processing Record 36 of Set 4 | angoram
# Processing Record 37 of Set 4 | college
# Processing Record 38 of Set 4 | borova
# Processing Record 39 of Set 4 | qaanaaq
# Processing Record 40 of Set 4 | kaitangata
# Processing Record 41 of Set 4 | dunedin
# Processing Record 42 of Set 4 | marau
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | kedrovyy
# Processing Record 45 of Set 4 | kavaratti
# Processing Record 46 of Set 4 | najran
# Processing Record 47 of Set 4 | sarangani
# Processing Record 48 of Set 4 | tura
# Processing Record 49 of Set 4 | ust-karsk
# Processing Record 50 of Set 4 | kavieng
# Processing Record 1 of Set 5 | poptun
# Processing Record 2 of Set 5 | yuancheng
# Processing Record 3 of Set 5 | pompeu
# Processing Record 4 of Set 5 | dingle
# Processing Record 5 of Set 5 | baruun-urt
# Processing Record 6 of Set 5 | dondo
# Processing Record 7 of Set 5 | longyearbyen
# Processing Record 8 of Set 5 | sindor
# Processing Record 9 of Set 5 | dzitbalche
# Processing Record 10 of Set 5 | nanortalik
# Processing Record 11 of Set 5 | west wendover
# Processing Record 12 of Set 5 | sao felix do xingu
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | sitka
# Processing Record 15 of Set 5 | sydney mines
# Processing Record 16 of Set 5 | havoysund
# Processing Record 17 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | athabasca
# Processing Record 20 of Set 5 | bengkulu
# Processing Record 21 of Set 5 | buala
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | baykit
# Processing Record 24 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 5 | san policarpo
# Processing Record 27 of Set 5 | la macarena
# Processing Record 28 of Set 5 | uva
# Processing Record 29 of Set 5 | gushikawa
# Processing Record 30 of Set 5 | sangar
# Processing Record 31 of Set 5 | tuktoyaktuk
# Processing Record 32 of Set 5 | berlevag
# Processing Record 33 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 5 | huangmei
# Processing Record 35 of Set 5 | silver city
# Processing Record 36 of Set 5 | zhigansk
# Processing Record 37 of Set 5 | vestmanna
# Processing Record 38 of Set 5 | sao geraldo do araguaia
# Processing Record 39 of Set 5 | kichera
# Processing Record 40 of Set 5 | mantua
# Processing Record 41 of Set 5 | eyl
# Processing Record 42 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 5 | gurupi
# Processing Record 44 of Set 5 | benemerito de las americas
# Processing Record 45 of Set 5 | khatanga
# Processing Record 46 of Set 5 | mecca
# Processing Record 47 of Set 5 | pathein
# Processing Record 48 of Set 5 | tual
# Processing Record 49 of Set 5 | tuatapere
# Processing Record 50 of Set 5 | alexandria
# Processing Record 1 of Set 6 | sabang
# Processing Record 2 of Set 6 | lohja
# Processing Record 3 of Set 6 | milos
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | nanchang
# Processing Record 6 of Set 6 | yellowknife
# Processing Record 7 of Set 6 | san quintin
# Processing Record 8 of Set 6 | saldanha
# Processing Record 9 of Set 6 | chandil
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | husavik
# Processing Record 12 of Set 6 | asadabad
# Processing Record 13 of Set 6 | saint-georges
# Processing Record 14 of Set 6 | tokat
# Processing Record 15 of Set 6 | paracuru
# Processing Record 16 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 17 of Set 6 | salisbury
# Processing Record 18 of Set 6 | soyo
# Processing Record 19 of Set 6 | khasan
# Processing Record 20 of Set 6 | lyubim
# Processing Record 21 of Set 6 | kargopol
# Processing Record 22 of Set 6 | west bay
# Processing Record 23 of Set 6 | tabas
# Processing Record 24 of Set 6 | jinchang
# Processing Record 25 of Set 6 | arlit
# Processing Record 26 of Set 6 | quartucciu
# Processing Record 27 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 6 | flagstaff
# Processing Record 29 of Set 6 | losheim
# Processing Record 30 of Set 6 | margate
# Processing Record 31 of Set 6 | diofior
# Processing Record 32 of Set 6 | hambantota
# Processing Record 33 of Set 6 | victoria
# Processing Record 34 of Set 6 | nisia floresta
# Processing Record 35 of Set 6 | fairbanks
# Processing Record 36 of Set 6 | isangel
# Processing Record 37 of Set 6 | port-cartier
# Processing Record 38 of Set 6 | iqaluit
# Processing Record 39 of Set 6 | georgetown
# Processing Record 40 of Set 6 | chifeng
# Processing Record 41 of Set 6 | pajapan
# Processing Record 42 of Set 6 | sola
# Processing Record 43 of Set 6 | noumea
# Processing Record 44 of Set 6 | grand gaube
# Processing Record 45 of Set 6 | banes
# Processing Record 46 of Set 6 | antofagasta
# Processing Record 47 of Set 6 | karpathos
# Processing Record 48 of Set 6 | gunnedah
# Processing Record 49 of Set 6 | maxixe
# Processing Record 50 of Set 6 | san vicente
# Processing Record 1 of Set 7 | cacequi
# Processing Record 2 of Set 7 | galle
# Processing Record 3 of Set 7 | yarmouth
# Processing Record 4 of Set 7 | prieska
# Processing Record 5 of Set 7 | muros
# Processing Record 6 of Set 7 | awjilah
# Processing Record 7 of Set 7 | nerchinskiy zavod
# Processing Record 8 of Set 7 | morondava
# Processing Record 9 of Set 7 | mirnyy
# Processing Record 10 of Set 7 | kyra
# Processing Record 11 of Set 7 | yenagoa
# Processing Record 12 of Set 7 | carnarvon
# Processing Record 13 of Set 7 | marshall
# Processing Record 14 of Set 7 | constitucion
# Processing Record 15 of Set 7 | whitehorse
# Processing Record 16 of Set 7 | gloversville
# Processing Record 17 of Set 7 | huarmey
# Processing Record 18 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 7 | pacific grove
# Processing Record 20 of Set 7 | kahului
# Processing Record 21 of Set 7 | la tuque
# Processing Record 22 of Set 7 | quatre cocos
# Processing Record 23 of Set 7 | chokurdakh
# Processing Record 24 of Set 7 | lucera
# Processing Record 25 of Set 7 | angoche
# Processing Record 26 of Set 7 | chitipa
# Processing Record 27 of Set 7 | mingaora
# Processing Record 28 of Set 7 | dukat
# Processing Record 29 of Set 7 | dubrovnik
# Processing Record 30 of Set 7 | almaznyy
# Processing Record 31 of Set 7 | chicama
# Processing Record 32 of Set 7 | komsomolskiy
# Processing Record 33 of Set 7 | kharan
# Processing Record 34 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 7 | belaya gora
# Processing Record 36 of Set 7 | pinheiro machado
# Processing Record 37 of Set 7 | qujing
# Processing Record 38 of Set 7 | carutapera
# Processing Record 39 of Set 7 | ipameri
# Processing Record 40 of Set 7 | yulara
# Processing Record 41 of Set 7 | poum
# Processing Record 42 of Set 7 | praia
# Processing Record 43 of Set 7 | luorong
# Processing Record 44 of Set 7 | luderitz
# Processing Record 45 of Set 7 | nabire
# Processing Record 46 of Set 7 | morant bay
# Processing Record 47 of Set 7 | fortuna
# Processing Record 48 of Set 7 | kenai
# Processing Record 49 of Set 7 | swellendam
# Processing Record 50 of Set 7 | imisli
# City not found. Skipping...
# Processing Record 1 of Set 8 | naze
# Processing Record 2 of Set 8 | merauke
# Processing Record 3 of Set 8 | linxia
# Processing Record 4 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 8 | brooks
# Processing Record 6 of Set 8 | mar del plata
# Processing Record 7 of Set 8 | camacha
# Processing Record 8 of Set 8 | zyryanka
# Processing Record 9 of Set 8 | naryan-mar
# Processing Record 10 of Set 8 | saint-pascal
# City not found. Skipping...
# Processing Record 11 of Set 8 | marondera
# Processing Record 12 of Set 8 | sobolevo
# Processing Record 13 of Set 8 | coalcoman
# City not found. Skipping...
# Processing Record 14 of Set 8 | codrington
# Processing Record 15 of Set 8 | gweta
# Processing Record 16 of Set 8 | tiarei
# Processing Record 17 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 18 of Set 8 | luba
# Processing Record 19 of Set 8 | lompoc
# Processing Record 20 of Set 8 | fairview
# Processing Record 21 of Set 8 | punta alta
# Processing Record 22 of Set 8 | yerofey pavlovich
# Processing Record 23 of Set 8 | zirandaro
# Processing Record 24 of Set 8 | santa maria
# Processing Record 25 of Set 8 | moranbah
# Processing Record 26 of Set 8 | sabha
# Processing Record 27 of Set 8 | brae
# Processing Record 28 of Set 8 | wajir
# Processing Record 29 of Set 8 | lithakia
# Processing Record 30 of Set 8 | santa marinella
# Processing Record 31 of Set 8 | chilliwack
# Processing Record 32 of Set 8 | leningradskiy
# Processing Record 33 of Set 8 | shubarkuduk
# Processing Record 34 of Set 8 | kaura namoda
# Processing Record 35 of Set 8 | amuntai
# Processing Record 36 of Set 8 | arkhangelos
# City not found. Skipping...
# Processing Record 37 of Set 8 | biltine
# Processing Record 38 of Set 8 | mayor pablo lagerenza
# Processing Record 39 of Set 8 | pangnirtung
# Processing Record 40 of Set 8 | sisimiut
# Processing Record 41 of Set 8 | barda
# Processing Record 42 of Set 8 | vaitape
# Processing Record 43 of Set 8 | fare
# Processing Record 44 of Set 8 | itoman
# Processing Record 45 of Set 8 | sao jose da coroa grande
# Processing Record 46 of Set 8 | rabo de peixe
# Processing Record 47 of Set 8 | thinadhoo
# Processing Record 48 of Set 8 | sandwick
# Processing Record 49 of Set 8 | inirida
# Processing Record 50 of Set 8 | eirunepe
# Processing Record 1 of Set 9 | rocha
# Processing Record 2 of Set 9 | billings
# Processing Record 3 of Set 9 | locri
# Processing Record 4 of Set 9 | maniitsoq
# Processing Record 5 of Set 9 | vallenar
# Processing Record 6 of Set 9 | ferrandina
# Processing Record 7 of Set 9 | tiksi
# Processing Record 8 of Set 9 | huanren
# Processing Record 9 of Set 9 | vila
# Processing Record 10 of Set 9 | shache
# Processing Record 11 of Set 9 | cape coast
# Processing Record 12 of Set 9 | mount isa
# Processing Record 13 of Set 9 | lorengau
# Processing Record 14 of Set 9 | fort wellington
# Processing Record 15 of Set 9 | tchollire
# Processing Record 16 of Set 9 | zhongshan
# Processing Record 17 of Set 9 | tabou
# Processing Record 18 of Set 9 | evensk
# Processing Record 19 of Set 9 | coolum beach
# Processing Record 20 of Set 9 | lodja
# Processing Record 21 of Set 9 | nathdwara
# Processing Record 22 of Set 9 | tuy hoa
# Processing Record 23 of Set 9 | cangzhou
# Processing Record 24 of Set 9 | atherton
# Processing Record 25 of Set 9 | talnakh
# Processing Record 26 of Set 9 | mahebourg
# Processing Record 27 of Set 9 | maarianhamina
# Processing Record 28 of Set 9 | moussoro
# Processing Record 29 of Set 9 | oistins
# Processing Record 30 of Set 9 | minnedosa
# Processing Record 31 of Set 9 | imeni poliny osipenko
# Processing Record 32 of Set 9 | tabat
# Processing Record 33 of Set 9 | lazurne
# Processing Record 34 of Set 9 | duldurga
# Processing Record 35 of Set 9 | narsaq
# Processing Record 36 of Set 9 | ormara
# Processing Record 37 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 9 | lebork
# Processing Record 39 of Set 9 | namibe
# Processing Record 40 of Set 9 | cabedelo
# Processing Record 41 of Set 9 | bilma
# Processing Record 42 of Set 9 | akdepe
# Processing Record 43 of Set 9 | wum
# Processing Record 44 of Set 9 | geraldton
# Processing Record 45 of Set 9 | coihaique
# Processing Record 46 of Set 9 | bloomfield
# Processing Record 47 of Set 9 | caravelas
# Processing Record 48 of Set 9 | mwinilunga
# Processing Record 49 of Set 9 | rio gallegos
# Processing Record 50 of Set 9 | maumere
# Processing Record 1 of Set 10 | ajaccio
# Processing Record 2 of Set 10 | bitung
# Processing Record 3 of Set 10 | bereda
# Processing Record 4 of Set 10 | katsuura
# Processing Record 5 of Set 10 | matamoros
# Processing Record 6 of Set 10 | areka
# Processing Record 7 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 10 | mazagao
# Processing Record 9 of Set 10 | lata
# Processing Record 10 of Set 10 | weinan
# Processing Record 11 of Set 10 | singaparna
# Processing Record 12 of Set 10 | ixtapa
# Processing Record 13 of Set 10 | bud
# Processing Record 14 of Set 10 | chortomlyk
# Processing Record 15 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 10 | himora
# City not found. Skipping...
# Processing Record 17 of Set 10 | korla
# Processing Record 18 of Set 10 | myaundzha
# Processing Record 19 of Set 10 | dehloran
# Processing Record 20 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 21 of Set 10 | strezhevoy
# Processing Record 22 of Set 10 | airai
# Processing Record 23 of Set 10 | boca do acre
# Processing Record 24 of Set 10 | karpogory
# Processing Record 25 of Set 10 | mayo
# Processing Record 26 of Set 10 | hengshui
# Processing Record 27 of Set 10 | burica
# City not found. Skipping...
# Processing Record 28 of Set 10 | bissau
# Processing Record 29 of Set 10 | salinopolis
# Processing Record 30 of Set 10 | avera
# Processing Record 31 of Set 10 | tilichiki
# Processing Record 32 of Set 10 | sidi ali
# Processing Record 33 of Set 10 | dikson
# Processing Record 34 of Set 10 | hamilton
# Processing Record 35 of Set 10 | christchurch
# Processing Record 36 of Set 10 | ostersund
# Processing Record 37 of Set 10 | nueva loja
# Processing Record 38 of Set 10 | nhulunbuy
# Processing Record 39 of Set 10 | verkhovye
# Processing Record 40 of Set 10 | turinsk
# Processing Record 41 of Set 10 | nosy varika
# Processing Record 42 of Set 10 | comodoro rivadavia
# Processing Record 43 of Set 10 | port macquarie
# Processing Record 44 of Set 10 | mitu
# Processing Record 45 of Set 10 | padang
# Processing Record 46 of Set 10 | goderich
# Processing Record 47 of Set 10 | sembabule
# Processing Record 48 of Set 10 | biloela
# Processing Record 49 of Set 10 | touros
# Processing Record 50 of Set 10 | kailua
# Processing Record 1 of Set 11 | chabahar
# Processing Record 2 of Set 11 | shyryayeve
# Processing Record 3 of Set 11 | iquitos
# Processing Record 4 of Set 11 | sorland
# Processing Record 5 of Set 11 | broken hill
# Processing Record 6 of Set 11 | alyangula
# Processing Record 7 of Set 11 | robertsport
# Processing Record 8 of Set 11 | kokkola
# Processing Record 9 of Set 11 | hervey bay
# Processing Record 10 of Set 11 | adrar
# Processing Record 11 of Set 11 | matongo
# Processing Record 12 of Set 11 | llanes
# Processing Record 13 of Set 11 | aklavik
# Processing Record 14 of Set 11 | tucumcari
# Processing Record 15 of Set 11 | lishu
# Processing Record 16 of Set 11 | aloleng
# Processing Record 17 of Set 11 | ahipara
# Processing Record 18 of Set 11 | cuyo
# Processing Record 19 of Set 11 | loei
# Processing Record 20 of Set 11 | mombasa
# Processing Record 21 of Set 11 | upernavik
# Processing Record 22 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 11 | gorontalo
# Processing Record 24 of Set 11 | bilibino
# Processing Record 25 of Set 11 | skjervoy
# Processing Record 26 of Set 11 | abu samrah
# Processing Record 27 of Set 11 | monrovia
# Processing Record 28 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 11 | challakere
# Processing Record 31 of Set 11 | hofn
# Processing Record 32 of Set 11 | tanjong sepat
# City not found. Skipping...
# Processing Record 33 of Set 11 | ouallam
# Processing Record 34 of Set 11 | along
# Processing Record 35 of Set 11 | udachnyy
# Processing Record 36 of Set 11 | port augusta
# Processing Record 37 of Set 11 | takoradi
# Processing Record 38 of Set 11 | dalianwan
# Processing Record 39 of Set 11 | nador
# Processing Record 40 of Set 11 | ciudad guayana
# Processing Record 41 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 11 | harper
# Processing Record 43 of Set 11 | stokmarknes
# Processing Record 44 of Set 11 | haines junction
# Processing Record 45 of Set 11 | kudahuvadhoo
# Processing Record 46 of Set 11 | mustasaari
# Processing Record 47 of Set 11 | kautokeino
# Processing Record 48 of Set 11 | bouna
# Processing Record 49 of Set 11 | bubaque
# Processing Record 50 of Set 11 | manicore
# Processing Record 1 of Set 12 | nanakuli
# Processing Record 2 of Set 12 | tocantinopolis
# City not found. Skipping...
# Processing Record 3 of Set 12 | salinas
# Processing Record 4 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 5 of Set 12 | kurri kurri
# Processing Record 6 of Set 12 | ginda
# Processing Record 7 of Set 12 | kutum
# Processing Record 8 of Set 12 | commerce
# Processing Record 9 of Set 12 | emba
# Processing Record 10 of Set 12 | nantucket
# Processing Record 11 of Set 12 | santa rosalia
# Processing Record 12 of Set 12 | oksfjord
# Processing Record 13 of Set 12 | qafsah
# City not found. Skipping...
# Processing Record 14 of Set 12 | elliot
# Processing Record 15 of Set 12 | lakatoro
# Processing Record 16 of Set 12 | sayyan
# Processing Record 17 of Set 12 | yumen
# Processing Record 18 of Set 12 | ust-charyshskaya pristan
# Processing Record 19 of Set 12 | meadow lake
# Processing Record 20 of Set 12 | jasper
# Processing Record 21 of Set 12 | concordia
# Processing Record 22 of Set 12 | juneau
# Processing Record 23 of Set 12 | sao joao da barra
# Processing Record 24 of Set 12 | hit
# Processing Record 25 of Set 12 | redlands
# Processing Record 26 of Set 12 | yar
# Processing Record 27 of Set 12 | icatu
# Processing Record 28 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 12 | lazaro cardenas
# Processing Record 30 of Set 12 | tahta
# Processing Record 31 of Set 12 | kathu
# Processing Record 32 of Set 12 | krasnoselkup
# Processing Record 33 of Set 12 | ucluelet
# Processing Record 34 of Set 12 | capinzal
# Processing Record 35 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 12 | ponta delgada
# Processing Record 37 of Set 12 | fernley
# Processing Record 38 of Set 12 | sao miguel do araguaia
# Processing Record 39 of Set 12 | san carlos
# Processing Record 40 of Set 12 | natal
# Processing Record 41 of Set 12 | russell
# Processing Record 42 of Set 12 | nebolchi
# Processing Record 43 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 44 of Set 12 | skegness
# Processing Record 45 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 46 of Set 12 | aksarka
# Processing Record 47 of Set 12 | saint-augustin
# Processing Record 48 of Set 12 | porto nacional
# Processing Record 49 of Set 12 | zacoalco
# City not found. Skipping...
# Processing Record 50 of Set 12 | fort nelson
# Processing Record 1 of Set 13 | torbat-e jam
# Processing Record 2 of Set 13 | panjwin
# City not found. Skipping...
# Processing Record 3 of Set 13 | shahrud
# Processing Record 4 of Set 13 | ilorin
# Processing Record 5 of Set 13 | raudeberg
# Processing Record 6 of Set 13 | tete
# Processing Record 7 of Set 13 | siva
# Processing Record 8 of Set 13 | sargatskoye
# Processing Record 9 of Set 13 | hasaki
# Processing Record 10 of Set 13 | sosnovo-ozerskoye
# Processing Record 11 of Set 13 | conde
# Processing Record 12 of Set 13 | amahai
# Processing Record 13 of Set 13 | los andes
# Processing Record 14 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | hastings
# Processing Record 17 of Set 13 | magdagachi
# Processing Record 18 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 20 of Set 13 | seydi
# Processing Record 21 of Set 13 | aquin
# Processing Record 22 of Set 13 | roebourne
# Processing Record 23 of Set 13 | carballo
# Processing Record 24 of Set 13 | dalbandin
# Processing Record 25 of Set 13 | lagoa
# Processing Record 26 of Set 13 | yima
# Processing Record 27 of Set 13 | koutsouras
# Processing Record 28 of Set 13 | barkot
# Processing Record 29 of Set 13 | melhus
# Processing Record 30 of Set 13 | paralimni
# Processing Record 31 of Set 13 | paamiut
# Processing Record 32 of Set 13 | astana
# Processing Record 33 of Set 13 | yantal
# Processing Record 34 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 13 | shingu
# Processing Record 36 of Set 13 | coari
# Processing Record 37 of Set 13 | kiruna
# Processing Record 38 of Set 13 | mancora
# Processing Record 39 of Set 13 | abdulino
# Processing Record 40 of Set 13 | ferrol
# Processing Record 41 of Set 13 | tanete
# Processing Record 42 of Set 13 | sulangan
# Processing Record 43 of Set 13 | half moon bay
# Processing Record 44 of Set 13 | hokota
# Processing Record 45 of Set 13 | nemea
# Processing Record 46 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 13 | winnemucca
# Processing Record 49 of Set 13 | sao filipe
# Processing Record 50 of Set 13 | utinga
# Processing Record 1 of Set 14 | manzhouli
# Processing Record 2 of Set 14 | sambava
# Processing Record 3 of Set 14 | goundam
# Processing Record 4 of Set 14 | weatherford
# Processing Record 5 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 14 | yerbogachen
# Processing Record 7 of Set 14 | kerema
# Processing Record 8 of Set 14 | clemencia
# Processing Record 9 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 14 | sovetskoye
# Processing Record 11 of Set 14 | kununurra
# Processing Record 12 of Set 14 | panama city
# Processing Record 13 of Set 14 | caraballeda
# Processing Record 14 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 14 | luanda
# Processing Record 16 of Set 14 | narrabri
# Processing Record 17 of Set 14 | palmer
# Processing Record 18 of Set 14 | kokopo
# Processing Record 19 of Set 14 | cap malheureux
# Processing Record 20 of Set 14 | tommot
# Processing Record 21 of Set 14 | chincha alta
# Processing Record 22 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 23 of Set 14 | escanaba
# Processing Record 24 of Set 14 | rehoboth
# Processing Record 25 of Set 14 | janakkala
# Processing Record 26 of Set 14 | shenjiamen
# Processing Record 27 of Set 14 | byron bay
# Processing Record 28 of Set 14 | surany
# Processing Record 29 of Set 14 | honiara
# Processing Record 30 of Set 14 | blonduos
# City not found. Skipping...
# Processing Record 31 of Set 14 | taltal
# Processing Record 32 of Set 14 | saryg-sep
# Processing Record 33 of Set 14 | te anau
# Processing Record 34 of Set 14 | concord
# Processing Record 35 of Set 14 | bolshaya murta
# City not found. Skipping...
# Processing Record 36 of Set 14 | muzhi
# Processing Record 37 of Set 14 | konstantinovka
# Processing Record 38 of Set 14 | gimli
# Processing Record 39 of Set 14 | glasgow
# Processing Record 40 of Set 14 | pando
# Processing Record 41 of Set 14 | yar-sale
# Processing Record 42 of Set 14 | sudbury
# Processing Record 43 of Set 14 | kankakee
# Processing Record 44 of Set 14 | san antonio
# Processing Record 45 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 14 | pisco
# Processing Record 47 of Set 14 | bandiagara
# Processing Record 48 of Set 14 | murgab
# Processing Record 49 of Set 14 | praya
# Processing Record 50 of Set 14 | labuhan
# Processing Record 1 of Set 15 | wentzville
# Processing Record 2 of Set 15 | poso
# Processing Record 3 of Set 15 | trofors
# Processing Record 4 of Set 15 | barra
# Processing Record 5 of Set 15 | blagoyevo
# Processing Record 6 of Set 15 | nikki
# Processing Record 7 of Set 15 | chimbote
# Processing Record 8 of Set 15 | waipawa
# Processing Record 9 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 15 | nargana
# Processing Record 11 of Set 15 | kencong
# Processing Record 12 of Set 15 | calabozo
# Processing Record 13 of Set 15 | ketchikan
# Processing Record 14 of Set 15 | mumford
# Processing Record 15 of Set 15 | tsaratanana
# Processing Record 16 of Set 15 | pyapon
# Processing Record 17 of Set 15 | dhekiajuli
# Processing Record 18 of Set 15 | grindavik
# Processing Record 19 of Set 15 | shimoda
# Processing Record 20 of Set 15 | nago
# Processing Record 21 of Set 15 | pilar
# Processing Record 22 of Set 15 | henties bay
# Processing Record 23 of Set 15 | tutoia
# Processing Record 24 of Set 15 | nome
# Processing Record 25 of Set 15 | batemans bay
# Processing Record 26 of Set 15 | manavalakurichi
# Processing Record 27 of Set 15 | manakara
# Processing Record 28 of Set 15 | bardsir
# Processing Record 29 of Set 15 | oussouye
# Processing Record 30 of Set 15 | tauranga
# Processing Record 31 of Set 15 | senanga
# Processing Record 32 of Set 15 | stabat
# Processing Record 33 of Set 15 | hvide sande
# Processing Record 34 of Set 15 | alice springs
# Processing Record 35 of Set 15 | wolmaranstad
# City not found. Skipping...
# Processing Record 36 of Set 15 | caapucu
# Processing Record 37 of Set 15 | loa janan
# Processing Record 38 of Set 15 | pochutla
# Processing Record 39 of Set 15 | orbetello
# Processing Record 40 of Set 15 | torres
# Processing Record 41 of Set 15 | turayf
# Processing Record 42 of Set 15 | normandin
# Processing Record 43 of Set 15 | bezhetsk
# Processing Record 44 of Set 15 | pailitas
# Processing Record 45 of Set 15 | morro bay
# Processing Record 46 of Set 15 | atambua
# Processing Record 47 of Set 15 | cockburn town
# Processing Record 48 of Set 15 | slave lake
# Processing Record 49 of Set 15 | rohnert park
# Processing Record 50 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 16 | cherskiy
# Processing Record 2 of Set 16 | birao
# Processing Record 3 of Set 16 | zhaoyang
# Processing Record 4 of Set 16 | gulshat
# City not found. Skipping...
# Processing Record 5 of Set 16 | tuburan
# Processing Record 6 of Set 16 | leninskoye
# Processing Record 7 of Set 16 | zhuanghe
# Processing Record 8 of Set 16 | santa cruz
# Processing Record 9 of Set 16 | kaoma
# Processing Record 10 of Set 16 | alofi
# Processing Record 11 of Set 16 | zhengjiatun
# Processing Record 12 of Set 16 | kota kinabalu
# Processing Record 13 of Set 16 | chara
# Processing Record 14 of Set 16 | nalut
# Processing Record 15 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 16 | banda aceh
# Processing Record 17 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 16 | taoudenni
# Processing Record 20 of Set 16 | san carlos de bariloche
# Processing Record 21 of Set 16 | cerro largo
# Processing Record 22 of Set 16 | cap-aux-meules
# Processing Record 23 of Set 16 | nipawin
# Processing Record 24 of Set 16 | hami
# Processing Record 25 of Set 16 | ewo
# Processing Record 26 of Set 16 | kegayli
# City not found. Skipping...
# Processing Record 27 of Set 16 | san roque
# Processing Record 28 of Set 16 | manguito
# Processing Record 29 of Set 16 | deputatskiy
# Processing Record 30 of Set 16 | antsohihy
# Processing Record 31 of Set 16 | laiwu
# Processing Record 32 of Set 16 | tezu
# Processing Record 33 of Set 16 | galveston
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     38.48        95         100
# 1  Richards Bay      ZA -28.7830   32.0377     66.22        86          67
# 2      Flinders      AU -34.5833  150.8552     55.38        88          95
# 3  Puerto Ayora      EC  -0.7393  -90.3518     71.55        87          58
# 4        Atuona      PF  -9.8000 -139.0333     77.56        72          15
# 5     Busselton      AU -33.6500  115.3333     57.81        78          67
# 6   Port Alfred      ZA -33.5906   26.8910     57.90        73           0
# 7        Albany      US  42.6001  -73.9662     93.29        43          30
# 8        Hobart      AU -42.8794  147.3294     39.27        92          20
# 9      Necochea      AR -38.5473  -58.7368     46.15        52          85
#
#    Wind Speed Current Description
# 0        0.38     overcast clouds
# 1        7.14       broken clouds
# 2        5.99          light rain
# 3        5.99       broken clouds
# 4       15.64          few clouds
# 5       10.85       broken clouds
# 6        6.11           clear sky
# 7        1.01    scattered clouds
# 8        6.91          few clouds
# 9        2.53     overcast clouds

# %%
# Save data frame to a csv file
city_data_df.to_csv("WeatherPy_Database.csv", index=False)
